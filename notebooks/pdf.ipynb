# %% [markdown]
# ## Create a Probability Density Functions

# %% [markdown]
# Based on a continuous random function, let's find random PDFs. Importantly, this is not a represenation of the the continuous function but a use of the continuous random function to create sufficiently different and random PDFs.

# %%
from py_files.random_function import create_random_function
from py_files.pdf import make_pdf, visualize_pdf

# %%
p = make_pdf(create_random_function())

# %%
visualize_pdf(p)
